# %% [markdown]
# The link of the project I am interested in: https://github.com/juniorcl/transaction-fraud-detection

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Table of Contents

# %% [markdown]
# * [1. Transaction Fraud Detection](#bullet1)
# * [2. Blocker Fraud Company](#bullet2)

# %% [markdown]
# # Transaction Fraud Detection <a class="anchor" id="bullet1"></a>

# %% [markdown]
# # Blocker Fraud Company <a class="anchor" id="bullet2"></a>

# %% [markdown]
# ## Top 3 Data Insights

# %% [markdown]
# ## Solution Strategy

# %% [markdown]
# * Data Description
# * Feature Engineering
# * Data Filtering
# * Exploratory Data Analysis

# %% [markdown]
# **All the fraud amount is greater than 10.000.**

# %% [markdown]
# *60% of fraud transaction occours using cash-out-type method.*
